# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
a = 12
b = 7

if a > b:
  res = a
else:
  res = b
  
print(res)
# Out:
# 12

# %%
a = 2
b = 7

res = a if a > b else b
  
print(res)
# Out:
# 7

# %%
a = -12
b = -7

res = abs(a) if a > b else abs(b)
  
print(res)
# Out:
# 7

# %%
s = "python"
t = "upper"

res = s.upper() if t == "upper" else s
  
print(res)
# Out:
# PYTHON

# %%
a = 12
b = 7

print([1, 2, a if a < b else b, 48, 21, 36])
# Out:
# [1, 2, 7, 48, 21, 36]

# %%
a = 12

print("a – " + ("even" if a %2 == 0 else "odd") + " number" )
print(f"a – {'even' if a %2 == 0 else 'odd'} number")
# Out:
# a – even number
# a – even number

# %%
a = 13

print(max(1, 5, a if a > 0 else b, 7, 9))
# Out:
# 13

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 2
b = 3
c = -4

d = (a if a > c else c) if a > b else (b if b > c else c)

print(d)
# Out:
# 3
