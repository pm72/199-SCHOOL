# %% [markdown]
# # სტრიქონის ინდექსები და ჭრები

# %%
s1 = "Panda"
s2 = 'Jupyter notebook'

text = '''I love Python, 
because it is very funny...
...
'''

print(s1)
print(s2)

print()

print(text)
text
# Out:
# Panda
# Jupyter notebook
#
# I love Python,
# because it is very funny...
# ...
# 'I love Python, \nbecause it is very funny...\n...\n'

# %% [markdown]
# სტრიქონი წარმოადგენს სიმბოლოების ნაკრებს, მასივს.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = "hello python"

print(s[0])
print(s[1])
print(s[12])
# Out:
# h
# e
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-25404144526a> in <module>
#       3 print(s[0])
#       4 print(s[1])
# ----> 5 print(s[12])
#
# IndexError: string index out of range

# %%
s = "hello python"

print(s[0])
print(s[1])
print(s[11])

print()

# ბოლო ინდექსი: len(s) - 1
print(len(s) - 1)
print(s[len(s) - 1])
# Out:
# h
# e
# n
#
# 11
# n

# %% [markdown]
# ასეთი მიდგომა ნებისმიერი სიგრძის სტრიქონებთანაა შესაძლებელი, გარდა ცარიელი (ნულოვანი სიგრძის) სტრიქონისა

# %%
s = ""
print(s[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-ebcf534f1f89> in <module>
#       1 s = ""
# ----> 2 print(s[0])
#
# IndexError: string index out of range

# %% [markdown]
# ბოლო ინდექსის გამოთვლა შესაძლებელია ასეთი ხერხითაც:
# ```python
# s = "Hello python"
# print(s[-1])
# ```

# %%
s = "Hello python"
print(s[-1])
print(s[-2])
# Out:
# n
# o

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Panda"[3])
# Out:
# d

# %% [markdown]
# როდესაც ვიყენებთ ინდექსს (`s[1], s[5], s[-2], ...`), ვღებულობთ ახალ სტრიქონს (ერთსიმბოლოიანი).

# %% [markdown]
# ### სტრიქონის ჭრები (slice)
#
# შესაძლებელია მრავალსიმბოლოიანი ახალი სტრიქონის მიღება ჩანაწერით.
#
# `s[start:stop:step]`
#
# ამას სტრიქონის ჭრა (slice) ეწოდება.
#
# `s[start:stop:step]` ბოლო ორი პარამტერის მითითება აუცილებელი არაა.

# %%
s = "Hello python"

print(s[1:3])
# Out:
# el

# %% [markdown]
# ამ შემთხვევაში იბეჭდება ახალი სტრიქონი ინდექსით 1-დან 3-მდე. 3 არ შედის ჭრის დიაპაზონში. დაიბეჭდება სიმბოლოები მდებარე 1 და 2 ინდექსზე.

# %%
s = "Hello python"

print(s[4:])
print(s[:5])
print(s[:])

print()

a = s[:]

print(id(s))
print(id(a))
# Out:
# o python
# Hello
# Hello python
#
# 3222146660400
# 3222146660400

# %%
s = "Hello python"

print(s[2:-2])
print(s[-2:2])
print(s[4:2])
# Out:
# llo pyth

# %%
s = "Hello python"

print(s[2:10:2])
# Out:
# lopt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = "Hello python"

print(s[2::3])
# Out:
# l tn

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
s = "Hello python"

print(s[:5:3])
print(s[::2])
print(s[::-1])
print(s[::-2])
# Out:
# Hl
# Hlopto
# nohtyp olleH
# nhy le

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# სტრიქონი წარმოადგენს არაცვალებად მონაცემთა ტიპს. შექმნილი სტრიქონის შეცვლა არ შეიძლება,

# %%
s = "hello python"

s[0] = 'H'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-1b1647e608e4> in <module>
#       1 s = "hello python"
#       2
# ----> 3 s[0] = 'H'
#
# TypeError: 'str' object does not support item assignment

# %%
s = "hello python"
print(id(s), s)

s = "H" + s[1:]

print(id(s), s)
# Out:
# 1438309423664 hello python
# 1438309640112 Hello python

# %% [markdown]
# ### რეზიუმე
#
# * სტრიქონი – სიმბოლოების ნაკრები
# * სტრიქონის სიმბოლოებთან წვდომა შესაძლებელია ინდექსაციის საშუალებით
# * სტრიქონიდან ქვესტრიქონის (გარკვეული სიმბოლოების) მიღება შესაძლებელია ჭრების (slice) საშუალებით
# * სტრიქონი არაცვალვადი ტიპის მონაცემთა სტრუქტურაა
# * სტრიქონის მოდიფიცირება (შეცვლა) შესაძლებელია ინდექსაციითა და ჭრებით
