# %%
4 < 2
# Out:
# False

# %%
a = 5
a < 0
# Out:
# False

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
x = -4

if x < 0:
  x = -x

print(x)
# Out:
# 4

# %%
a = eval(input("a = "))
b = eval(input("b = "))

if a < b:
  a, b = b, a
  
print(f"{a = }, {b = }")
# Out:
# a = 3
# b = 12
# a = 12, b = 3

# %%
x = eval(input("x: "))

if x >= -4 and x <= 10:
  print("x in range [-4; 10]")
# Out:
# x: 5
# x in range [-4; 10]

# %%
x = eval(input("x: "))

if -4 <= x<= 10:
  print("x in range [-4; 10]")
# Out:
# x: 5
# x in range [-4; 10]

# %%
x = eval(input("x: "))

if x:
  print("x is True")
# Out:
# x: 25
# x is True

# %%
x = eval(input("x: "))

if True:
  print("x is True")
# Out:
# x: 0
# x is True

# %%
marks = [6, 6, 8, 4, 8]

if 4 in marks:
  print("Student will be expelled")
# Out:
# Student will be expelled

# %%
marks = [6, 6, 8, 4, 8]

if 4 in marks:
  print("Student will be expelled")
else:
  print("The student has successfully passed the session")
# Out:
# Student will be expelled

# %%
marks = [6, 6, 8, 10, 8]

if 4 in marks:
  print("Student will be expelled")
else:
  print("The student has successfully passed the session")
# Out:
# The student has successfully passed the session

# %%
x = eval(input("x: "))

if x < 0:
  print("X is negative")
else:
  print("X is positive")
# Out:
# x: -1
# X is negative

# %%
x = eval(input("x: "))

if x % 2 == 0:
  print("X is even")
else:
  print("X is odd")
# Out:
# x: 8
# X is even
