# %% [markdown]
# # ცვლადები, მინიჭების ოპერატორი, type და id ფუნქციები

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-5.png](attachment:image-5.png)

# %%
a = 7
print(a)
# Out:
# 7

# %%
a = 7
print(a)
print(var_a)   # var_a ცვლადი არ არსებობს
# Out:
# 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a8dac5ce538a> in <module>
#       1 a = 7
#       2 print(a)
# ----> 3 print(var_a)
#
# NameError: name 'var_a' is not defined

# %%
a = 7
print(a)

var_a = "Hello"
print(var_a)
# Out:
# 7
# Hello

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-5.png](attachment:image-5.png)

# %%
a = 7
a = 6.8
print(a)
# Out:
# 6.8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 7
b = a
print(a)
print(b)
# Out:
# 7
# 7

# %%
a = 7
b = "Hello"
b = 8
b = -8.4
print(a, b)
# Out:
# 7 -8.4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = b = c = 0  # კასკადური მინიჭება
print(a, b, c)
print(id(a), id(b), id(c))
# Out:
# 0 0 0
# 140711584605968 140711584605968 140711584605968

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a, b = 1, 2  # მრავალმხრივი მინიჭება
print(a, b)
print(id(a), id(b))
# Out:
# 1 2
# 140711584606000 140711584606032

# %%
# მნიშვნელობების გაცვლა ორ ცვლადს შორის
a, b = 1, 2
print(a, b)

a, b = b, a
print(a, b)
print(id(a), id(b))
# Out:
# 1 2
# 2 1
# 140711584606032 140711584606000

# %%
a = 6
print(a)
print(type(a))
# Out:
# 6
# <class 'int'>

# %%
x = 5.8
s = "Hello"

print(type(x))
print(type(s))
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ### ცვლადების სახელები
#
# 1. ცვლადის სახელი სასურველია იყოს არსებით სახელი (ვინ? რა?)
# 2. ცვლადის სახელი სასურველია აზრობრივი იყოს და ასახავდეს მონაცემთა არსს
# 3. ცვლადის სახელში დაშვებული სიმბოლოები: პირველი სიმბოლო – ლათინური ანბანის ასო `a-z`, `A-Z` ან ქვედა ტირე. დანარჩენი სიმბოლოები შეიძლება იყოს ქვედა ტირე ან (და) ლათინური ანბანის ასოები ან რიცხვები `0-9`.
#
# მაგ.:
#
# `name`, `msg1`, `f_name`, `last_name`, `_arg`, `__arg_1`, `__doc_name__` და ა.შ.
#
# არ შეიძლება ცვლ;ადის სახელი ციფრით იწყებოდეს

# %%
msg = "Message"
count = 0

arg = 0
Arg = 0  # სხვადასხვა ცვლადებია arg და Arg

# True, False, in ... გასაღები სიტყვებია (python-ში დარეზერვებული)
# და არ შეიძლება გამოიყენებოდეს ცვლადის სახით
True = 5
# Out:
#   File "<ipython-input-4-5d4517af7b38>", line 9
#     True = 5
#     ^
# SyntaxError: cannot assign to True

# %%
# python-ში დარეზერვებული ყველა სიტყვა
help()
# Out:
# Welcome to Python 3.8's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.8/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help>
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %%
print = 5
print(6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-fa7df8106b45> in <module>
#       1 print = 5
# ----> 2 print(6)
#
# TypeError: 'int' object is not callable
